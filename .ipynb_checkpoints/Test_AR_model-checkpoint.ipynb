# %%
# !pip install jax
# !pip install jaxlib
# Out:
# ...
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\nutel\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\nutel\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\nutel\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\nutel\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\nutel\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\nutel\appdata\local\programs\python\python39\lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\nutel\appdata\local\programs\python\python39\lib\site-packages)
# ...

# %%
import jax.numpy as jnp
import matplotlib.pyplot as plt
import jax.random as rnd

# %matplotlib notebook
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12332/200015566.py in <module>
# ----> 1 import jax.numpy as jnp
#       2 import matplotlib.pyplot as plt
#       3 import jax.random as rnd
#       4
#       5 get_ipython().run_line_magic('matplotlib', 'notebook')
#
# c:\users\nutel\appdata\local\programs\python\python39\lib\site-packages\jax\__init__.py in <module>
#      19
#      20 # flake8: noqa: F401
# ---> 21 from .config import config
#      22 from .api import (
#      23   ad,  # TODO(phawkins): update users to avoid this.
#
# c:\users\nutel\appdata\local\programs\python\python39\lib\site-packages\jax\config.py in <module>
#      17 import threading
#      18 from typing import Optional
# ---> 19 from jax import lib
#      20
#      21 def bool_env(varname: str, default: bool) -> bool:
#
# ...

# %%
# Verify gaussian shape
x = jnp.linspace(-7.5, 7.5, 101)
x1, x2 = jnp.meshgrid(x, x)
Sigma = jnp.linalg.inv(cov)
p = jnp.zeros( (101,101) )
for k in range(101):
    for j in range(101):
        v = jnp.array([x[k], x[j]])
        p[k,j] = -0.5*v.T@Sigma@v

p = np.exp(p)


fig = plt.figure()
ax = fig.add_subplot(111)



im = ax.contourf(x, x, p, levels=10)
ax.contour(x, x, p, levels=10, colors='black', linewidths=.5)


pts = np.random.multivariate_normal([0, 0], cov, size=800).T
ax.scatter(pts[0], pts[1])

cbar = plt.colorbar(im)
cbar.set_label(r'$\log \tilde{P}(\phi_1, \phi_2)$')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
v.shape
# Out:
# (2, 20, 20)

# %%
# Out:
# (20, 20, 20, 20)
